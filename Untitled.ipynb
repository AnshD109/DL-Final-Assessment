# %%
import pandas as pd

# Load the full dataset
df = pd.read_csv("fraudTrain.csv")

# Take a random sample (5,000 rows)
fraud_sample = df.sample(n=5000, random_state=42)

# Save sample for Streamlit
fraud_sample.to_csv("fraud_sample.csv", index=False)

print("fraud_sample.csv created successfully!")
print(fraud_sample.shape)
# Out:
# fraud_sample.csv created successfully!
# (5000, 23)
